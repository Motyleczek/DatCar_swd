# %% [markdown]
# ## 1. Import bibliotek i wczytanie danych

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../../DatCar_swd/Data/cars.csv")
df.head()
# Out:
#     Marka     Model Skrzynia biegów   Kolor   Nadwozie  Przebieg  \
# 0  Subaru   Outback       automatic  silver  universal    190000
# 1  Subaru   Outback       automatic    blue  universal    290000
# 2  Subaru  Forester       automatic     red        suv    402000
# 3  Subaru   Impreza      mechanical    blue      sedan     10000
# 4  Subaru    Legacy       automatic   black  universal    280000
#
#    Rok produkcji  Pojemność Rodzaj paliwa      Cena  Gwarancja
# 0           2010        2.5      gasoline  10900.00      False
# 1           2002        3.0      gasoline   5000.00      False
# 2           2001        2.5      gasoline   2800.00      False
# 3           1999        3.0      gasoline   9999.00      False
# 4           2001        2.5      gasoline   2134.11      False

# %% [markdown]
# ## 2. Zbiór danych, brakujące wartości

# %%
df.shape
# Out:
# (38531, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marka            38531 non-null  object
#  1   Model            38531 non-null  object
#  2   Skrzynia biegów  38531 non-null  object
#  3   Kolor            38531 non-null  object
#  4   Nadwozie         38531 non-null  object
#  5   Przebieg         38531 non-null  int64
#  6   Rok produkcji    38531 non-null  int64
#  7   Pojemność        38521 non-null  float64
#  8   Rodzaj paliwa    38531 non-null  object
#  9   Cena             38531 non-null  float64
#  10  Gwarancja        38531 non-null  bool
# dtypes: bool(1), float64(2), int64(2), object(6)
# memory usage: 3.0+ MB

# %%
df.isna().sum()
# Out:
# Marka               0
# Model               0
# Skrzynia biegów     0
# Kolor               0
# Nadwozie            0
# Przebieg            0
# Rok produkcji       0
# Pojemność          10
# Rodzaj paliwa       0
# Cena                0
# Gwarancja           0
# dtype: int64

# %%
df.dropna(inplace=True) #wywalam bo to tylko 10 modeli
df.shape
# Out:
# (38521, 11)

# %% [markdown]
# ## 3. Analiza- dane numeryczne i kategoryczne

# %%
df['Rok produkcji'].describe()
# Out:
# count    38521.000000
# mean      2002.940863
# std          8.064761
# min       1942.000000
# 25%       1998.000000
# 50%       2003.000000
# 75%       2009.000000
# max       2019.000000
# Name: Rok produkcji, dtype: float64

# %%
df["Age"] = 2022 - df['Rok produkcji'] #dodaję kolumnę Age
df.head()
# Out:
#     Marka     Model Skrzynia biegów   Kolor   Nadwozie  Przebieg  \
# 0  Subaru   Outback       automatic  silver  universal    190000
# 1  Subaru   Outback       automatic    blue  universal    290000
# 2  Subaru  Forester       automatic     red        suv    402000
# 3  Subaru   Impreza      mechanical    blue      sedan     10000
# 4  Subaru    Legacy       automatic   black  universal    280000
#
#    Rok produkcji  Pojemność Rodzaj paliwa      Cena  Gwarancja  Age
# 0           2010        2.5      gasoline  10900.00      False   12
# 1           2002        3.0      gasoline   5000.00      False   20
# 2           2001        2.5      gasoline   2800.00      False   21
# 3           1999        3.0      gasoline   9999.00      False   23
# 4           2001        2.5      gasoline   2134.11      False   21

# %% [markdown]
# #### a) Numeric data

# %%
df_numeric = df.select_dtypes(include=['int64','float64'])
df_numeric.head()
# Out:
#    Przebieg  Rok produkcji  Pojemność      Cena  Age
# 0    190000           2010        2.5  10900.00   12
# 1    290000           2002        3.0   5000.00   20
# 2    402000           2001        2.5   2800.00   21
# 3     10000           1999        3.0   9999.00   23
# 4    280000           2001        2.5   2134.11   21

# %%
df_numeric.describe()
# Out:
#              Przebieg  Rok produkcji     Pojemność          Cena           Age
# count    38521.000000   38521.000000  38521.000000  38521.000000  38521.000000
# mean    248910.074427    2002.940863      2.055161   6637.160884     19.059137
# std     136059.499858       8.064761      0.671178   6425.198996      8.064761
# min          0.000000    1942.000000      0.200000      1.000000      3.000000
# 25%     158000.000000    1998.000000      1.600000   2100.000000     13.000000
# 50%     250000.000000    2003.000000      2.000000   4800.000000     19.000000
# 75%     325000.000000    2009.000000      2.300000   8950.000000     24.000000
# max    1000000.000000    2019.000000      8.000000  50000.000000     80.000000

# %% [markdown]
# Najprawdopodobniej nie ma tu "ukrytych" pod innym aliasem NaN-ów.

# %%
plt.figure(figsize=(16,12))

plt.subplot(221)
plt1 = df["Przebieg"].plot(kind='box')
plt.title('Przebieg')
plt1.set(xlabel = 'Przebieg')
plt.grid()

plt.subplot(222)
plt2 = df['Age'].plot(kind='box')
plt.title('Age')
plt2.set(xlabel = 'Age')
plt.grid()

plt.subplot(223)
plt3 = df["Pojemność"].plot(kind='box')
plt.title('Pojemność')
plt3.set(xlabel = 'Pojemność')
plt.grid()

plt.subplot(224)
plt4 = df["Cena"].plot(kind='box')
plt.title('Cena')
plt4.set(xlabel = 'Cena')
plt.grid()

plt.show()

# %% [markdown]
# Najprawdopodobniej nie ma tu "ukrytych" pod innym aliasem NaN-ów.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_numeric.corr(),annot=True)
plt.show()

# %% [markdown]
# **Każda z cech numerycznych ma istotny wpływ na cenę, największą rolę odgrywa cecha "Rok produkcji"/"Age"- korelacja aż 71%.**

# %% [markdown]
# #### b) Categorical data

# %%
df_categorical = df.select_dtypes(include=['object','bool'])
df_categorical.head()
# Out:
#     Marka     Model Skrzynia biegów   Kolor   Nadwozie Rodzaj paliwa  \
# 0  Subaru   Outback       automatic  silver  universal      gasoline
# 1  Subaru   Outback       automatic    blue  universal      gasoline
# 2  Subaru  Forester       automatic     red        suv      gasoline
# 3  Subaru   Impreza      mechanical    blue      sedan      gasoline
# 4  Subaru    Legacy       automatic   black  universal      gasoline
#
#    Gwarancja
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
plt.figure(figsize=(16,24))

plt.subplot(321)
plt1 = df["Marka"].value_counts().plot(kind='bar')
plt.title('Marka')
plt1.set(xlabel = 'Car company', ylabel='Ilość wystąpień')

plt.subplot(322)
plt2 = df['Skrzynia biegów'].value_counts().plot(kind='bar')
plt.title('Skrzynia biegów')
plt2.set(xlabel = 'Typ skrzyni biegów', ylabel='Ilość wystąpień')

plt.subplot(323)
plt3 = df["Kolor"].value_counts().plot(kind='bar')
plt.title('Kolor')
plt3.set(xlabel = 'Kolor', ylabel='Ilość wystąpień')

plt.subplot(324)
plt4 = df["Nadwozie"].value_counts().plot(kind='bar')
plt.title('Nadwozie')
plt4.set(xlabel = 'Typ nadwozia', ylabel='Ilość wystąpień')

plt.subplot(325)
plt5 = df["Rodzaj paliwa"].value_counts().plot(kind='bar')
plt.title('Rodzaj paliw')
plt5.set(xlabel = 'Rodzaj paliwa', ylabel='Ilość wystąpieńe')

plt.subplot(326)
plt6 = df["Gwarancja"].value_counts().plot(kind='bar')
plt.title('Gwarancja')
plt6.set(xlabel = 'Gwarancja', ylabel='Ilość wystąpień')

plt.show()

# %%
df_categorical.columns
# Out:
# Index(['Marka', 'Model', 'Skrzynia biegów', 'Kolor', 'Nadwozie',
#        'Rodzaj paliwa', 'Gwarancja'],
#       dtype='object')

# %%
for col in df_categorical.columns:
    print(df[col].unique(),"\n")
# Out:
# ['Subaru' 'LADA' 'Dodge' 'УАЗ' 'Kia' 'Opel' 'Москвич' 'Alfa Romeo' 'Acura'
#  'Dacia' 'Lexus' 'Mitsubishi' 'Lancia' 'Citroen' 'Mini' 'Jaguar' 'Porsche'
#  'SsangYong' 'Daewoo' 'Geely' 'ВАЗ' 'Fiat' 'Ford' 'Renault' 'Seat' 'Rover'
#  'Volkswagen' 'Lifan' 'Jeep' 'Cadillac' 'Audi' 'ЗАЗ' 'Toyota' 'ГАЗ'
#  'Volvo' 'Chevrolet' 'Great Wall' 'Buick' 'Pontiac' 'Lincoln' 'Hyundai'
#  'Nissan' 'Suzuki' 'BMW' 'Mazda' 'Land Rover' 'Iveco' 'Skoda' 'Saab'
#  'Infiniti' 'Chery' 'Honda' 'Mercedes-Benz' 'Peugeot' 'Chrysler']
#
# ['Outback' 'Forester' 'Impreza' ... '180' 'Vision' 'Aspen']
#
# ['automatic' 'mechanical']
#
# ['silver' 'blue' 'red' 'black' 'grey' 'other' 'brown' 'white' 'green'
#  'violet' 'orange' 'yellow']
#
# ['universal' 'suv' 'sedan' 'hatchback' 'liftback' 'minivan' 'minibus'
#  'van' 'pickup' 'coupe' 'cabriolet' 'limousine']
#
# ['gasoline' 'diesel']
#
# [False  True]

# %% [markdown]
# Najprawdopodobniej nie ma tu "ukrytych" pod innym aliasem NaN-ów.

# %% [markdown]
# ## 4. Dummy variables

# %% [markdown]
# "We have around 45 different Car Manufacturing Companies with Different Model Names. If we create dummy variables for all these names, it will result in large number of coulmns which is not feasible for model building. Hence, we will try and create different groups based on Average Price of the cars."

# %%
temp = df.copy()

table = temp.groupby(['Marka'])['Cena'].mean()
temp = temp.merge(table.reset_index(), how='left', on='Marka')
print(table)
# Out:
# Marka
# Acura            12772.885909
# Alfa Romeo        2688.550097
# Audi              7154.944923
# BMW               9532.098405
# Buick            12876.319149
# Cadillac         11093.124651
# Chery             4545.978103
# Chevrolet         8863.759885
# Chrysler          4995.491780
# Citroen           4433.126204
# Dacia             5342.751525
# Daewoo            1576.608733
# Dodge             5608.011953
# Fiat              2979.752689
# Ford              4993.888044
# Geely             7769.232535
# Great Wall        6423.760278
# Honda             6515.096474
# Hyundai           7926.190394
# Infiniti         13794.604938
# Iveco            10052.317122
# Jaguar           17813.000000
# Jeep             10912.489439
# Kia               8156.095526
# LADA              7598.681370
# Lancia            2901.508370
# Land Rover       15195.300380
# Lexus            17130.560845
# Lifan             8280.536170
# Lincoln           9737.472222
# Mazda             4731.527101
# Mercedes-Benz     9389.817072
# Mini             13133.700882
# Mitsubishi        5416.170800
# Nissan            6386.446010
# Opel              4425.992900
# Peugeot           4382.217727
# Pontiac           4363.544048
# Porsche          18629.823770
# Renault           4557.398873
# Rover             1734.242213
# Saab              4130.585370
# Seat              3868.015347
# Skoda            13795.448466
# SsangYong         7719.322405
# Subaru            7522.094605
# Suzuki            5302.598761
# Toyota            9798.152456
# Volkswagen        6428.902578
# Volvo             8416.341540
# ВАЗ               1518.921289
# ГАЗ               3889.731900
# ЗАЗ               1360.211190
# Москвич            978.912182
# УАЗ               3443.123784
# Name: Cena, dtype: float64

# %%
table.plot(kind='box')
plt.grid()
plt.title("Średnia cena różnych marek")
plt.show()

# %%
bins = [0,0.2,0.5,0.7,0.9,1]
#bins = [0,5000,8000,11000,15000,100000]
kat_bins = ['Budget','Budget_plus','Medium','Medium_plus','Highend']

# %%
temp.head()
# Out:
#     Marka     Model Skrzynia biegów   Kolor   Nadwozie  Przebieg  \
# 0  Subaru   Outback       automatic  silver  universal    190000
# 1  Subaru   Outback       automatic    blue  universal    290000
# 2  Subaru  Forester       automatic     red        suv    402000
# 3  Subaru   Impreza      mechanical    blue      sedan     10000
# 4  Subaru    Legacy       automatic   black  universal    280000
#
#    Rok produkcji  Pojemność Rodzaj paliwa    Cena_x  Gwarancja  Age  \
# 0           2010        2.5      gasoline  10900.00      False   12
# 1           2002        3.0      gasoline   5000.00      False   20
# 2           2001        2.5      gasoline   2800.00      False   21
# 3           1999        3.0      gasoline   9999.00      False   23
# 4           2001        2.5      gasoline   2134.11      False   21
#
#         Cena_y
# 0  7522.094605
# 1  7522.094605
# 2  7522.094605
# 3  7522.094605
# 4  7522.094605

# %%
df['Kategoria'] = pd.qcut(temp['Cena_y'], bins, labels=kat_bins)
#df['Kategoria'] = pd.cut(temp['Cena_y'], bins,  right=False, labels=kat_bins)
df.head()
# Out:
#     Marka     Model Skrzynia biegów   Kolor   Nadwozie  Przebieg  \
# 0  Subaru   Outback       automatic  silver  universal    190000
# 1  Subaru   Outback       automatic    blue  universal    290000
# 2  Subaru  Forester       automatic     red        suv    402000
# 3  Subaru   Impreza      mechanical    blue      sedan     10000
# 4  Subaru    Legacy       automatic   black  universal    280000
#
#    Rok produkcji  Pojemność Rodzaj paliwa      Cena  Gwarancja  Age Kategoria
# 0           2010        2.5      gasoline  10900.00      False   12    Medium
# 1           2002        3.0      gasoline   5000.00      False   20    Medium
# 2           2001        2.5      gasoline   2800.00      False   21    Medium
# 3           1999        3.0      gasoline   9999.00      False   23    Medium
# 4           2001        2.5      gasoline   2134.11      False   21    Medium

# %%
df['Kategoria'].unique()
# Out:
# ['Medium', 'Budget_plus', 'Budget', 'Medium_plus', 'Highend', NaN]
# Categories (5, object): ['Budget' < 'Budget_plus' < 'Medium' < 'Medium_plus' < 'Highend']

# %%
kat_count = df['Kategoria'].value_counts()
kat_count.plot(kind='bar')
plt.grid()
plt.show()

# %%
df[df['Kategoria'].isna()]   #WHY, TO NIE MA SENSU
# Out:
#           Marka          Model Skrzynia biegów   Kolor   Nadwozie  Przebieg  \
# 38521  Chrysler           Neon      mechanical   green      sedan    260000
# 38522  Chrysler     PT Cruiser       automatic   other  hatchback    207605
# 38523  Chrysler  Grand Voyager      mechanical   black    minivan    278000
# 38524  Chrysler            300       automatic  silver      sedan    240000
# 38525  Chrysler        Voyager      mechanical  violet    minivan    317000
# 38526  Chrysler            300       automatic  silver      sedan    290000
# 38527  Chrysler     PT Cruiser      mechanical    blue  hatchback    321000
# 38528  Chrysler            300       automatic    blue      sedan    777957
# 38529  Chrysler     PT Cruiser      mechanical   black    minivan     20000
# 38530  Chrysler        Voyager       automatic  silver    minivan    297729
#
#        Rok produkcji  Pojemność Rodzaj paliwa     Cena  Gwarancja  Age  \
# 38521           1995        2.0      gasoline   550.00      False   27
# 38522           2004        2.4      gasoline  4000.00      False   18
# 38523           1999        2.5        diesel  4220.81      False   23
# 38524           2001        3.5      gasoline  3000.00      False   21
# 38525           1999        2.0      gasoline  3300.00      False   23
# 38526           2000        3.5      gasoline  2750.00      False   22
# 38527           2004        2.2        diesel  4800.00      False   18
# 38528           2000        3.5      gasoline  4300.00      False   22
# 38529           2001        2.0      gasoline  4000.00      False   21
# 38530           2000        2.4      gasoline  3200.00      False   22
#
#       Kategoria
# 38521       NaN
# 38522       NaN
# 38523       NaN
# 38524       NaN
# 38525       NaN
# 38526       NaN
# 38527       NaN
# 38528       NaN
# 38529       NaN
# 38530       NaN
